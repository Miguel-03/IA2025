# %% [markdown]
# <a href="https://colab.research.google.com/github/Miguel-03/IA2025/blob/main/ULIBRO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #QUEST ULIBRO

# %% [markdown]
# ## Fotos ULIBRO

# %% [markdown]
# ![ULIBRO1 (2).jpeg](data:image/jpeg;base64,...)
